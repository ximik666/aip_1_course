# %% [markdown]
# 1. Создать матрицу, ввод числа строк и столбцов, элементов матрицы организовать с клавиатуры. При создании матрицы использовать только 1 цикл for
# 2. Вывести все (4) треугольника матрицы, образованные главной и побочной диагоналями, и строками и столбцами матрицы.
