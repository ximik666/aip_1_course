# %% [markdown]
# 1. Сгенерировать строку, состоящую из n случайных символов(вводится с клавиатуры), символы берутся из строки stroka (вводится с клавиатуры). В полученной строке переместить все символы равные 1 символу строки в начало, а все символы равные последнему элементу в конец строки. Например
#
# ""
# n = 5
# stroka = 'abc'
# gen_stroka = 'abcab' # данная строка сгенерированная
# otvet = 'aacbb'
# ""
#
# 2. Дан список из N (N≤200000) элементов,которые принимают целые значения от 0 до 1000.
# Отсортируйте этот список в порядке возрастания элементов. Выведите полученный список.
#
# Решение оформите в виде функции sort_element(A), которая модифицирует передаваемый ей список.Использовать встроенные функции сортировки нельзя.
