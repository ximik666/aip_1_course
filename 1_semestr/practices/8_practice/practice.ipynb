# %%
# Написать программу, которая перемножает все цифры некого числа, пока оно не станет меньше 8. Число всегда больше нуля.

# %%
# Ваша задача — написать программу, которая добавляет один к первой цифре в строке. Если же строка пустая или цифр в начале не обнаружилось — добавляет их самостоятельно.

# Пример:

# 'foo' -> 1foo
# '6agent00' -> 7agent00

# %%
# Ваша задача — написать функцию, которая перемещает все нули в конец числа. Функция принимает число, а ваша задача — изменить его так, что бы нули оказались в конце числа.

# 1010 -> 1100
# 1099 -> 1990
